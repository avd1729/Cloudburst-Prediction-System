# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('C:/Users/Aravind/Work/PROJECTS/Cloudburst-Prediction-System/data/raw/IndianWeatherRepository.csv')

# %%
'''from pandas_profiling import ProfileReport
df = pd.DataFrame(data)
profile = ProfileReport(df)
profile.to_file('C:/Users/Aravind/Work/PROJECTS/Cloudburst-Prediction-System/reports/eda.html')'''
# Out:
# "from pandas_profiling import ProfileReport\ndf = pd.DataFrame(data)\nprofile = ProfileReport(df)\nprofile.to_file('C:/Users/Aravind/Work/PROJECTS/Cloudburst-Prediction-System/reports/eda.html')"

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9840 entries, 0 to 9839
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       9840 non-null   object
#  1   location_name                 9840 non-null   object
#  2   region                        9840 non-null   object
#  3   latitude                      9840 non-null   float64
#  4   longitude                     9840 non-null   float64
#  5   timezone                      9840 non-null   object
#  6   last_updated_epoch            9840 non-null   int64
#  7   last_updated                  9840 non-null   object
#  8   temperature_celsius           9840 non-null   float64
#  9   temperature_fahrenheit        9840 non-null   float64
#  10  condition_text                9840 non-null   object
#  11  wind_mph                      9840 non-null   float64
# ...

# %%
data.head(10)
# Out:
#   country location_name          region  latitude  longitude      timezone
# 0   India    Ashoknagar  Madhya Pradesh     24.57      77.72  Asia/Kolkata  \
# 1   India        Raisen  Madhya Pradesh     23.33      77.80  Asia/Kolkata
# 2   India    Chhindwara  Madhya Pradesh     22.07      78.93  Asia/Kolkata
# 3   India         Betul  Madhya Pradesh     21.86      77.93  Asia/Kolkata
# 4   India   Hoshangabad  Madhya Pradesh     22.75      77.72  Asia/Kolkata
#
#    last_updated_epoch      last_updated  temperature_celsius
# 0          1693286100  2023-08-29 10:45                 27.5  \
# 1          1693286100  2023-08-29 10:45                 27.5
# 2          1693286100  2023-08-29 10:45                 26.3
# 3          1693286100  2023-08-29 10:45                 25.6
# 4          1693286100  2023-08-29 10:45                 27.2
#
#    temperature_fahrenheit  ... air_quality_PM2.5  air_quality_PM10
# 0                    81.5  ...              12.6              18.5  \
# ...

# %%
data.describe()
# Out:
#           latitude    longitude  last_updated_epoch  temperature_celsius
# count  9840.000000  9840.000000        9.840000e+03          9840.000000  \
# mean     23.106256    80.229436        1.694004e+09            25.225061
# std       5.797599     5.761152        4.487798e+05             3.838239
# min       8.080000    68.970000        1.693286e+09            -2.600000
# 25%      20.270000    76.070000        1.693612e+09            23.600000
# 50%      23.970000    78.670000        1.694041e+09            25.600000
# 75%      26.772500    83.900000        1.694387e+09            27.300000
# max      34.570000    95.800000        1.694732e+09            38.300000
#
#        temperature_fahrenheit     wind_mph     wind_kph  wind_degree
# count             9840.000000  9840.000000  9840.000000  9840.000000  \
# mean                77.405234     6.104299     9.826657   194.218496
# std                  6.909241     3.556082     5.718722    98.014747
# ...

# %%
data['country'].value_counts()
# Out:
# country
# India    9840
# Name: count, dtype: int64

# %%
data['timezone'].value_counts()
# Out:
# timezone
# Asia/Kolkata    9786
# Asia/Dhaka        36
# Asia/Karachi      18
# Name: count, dtype: int64

# %%
data['last_updated'].value_counts()
# Out:
# last_updated
# 2023-09-01 05:15    541
# 2023-08-29 10:45    540
# 2023-09-03 05:15    538
# 2023-09-12 04:30    537
# 2023-09-14 20:00    536
#                    ...
# 2023-09-02 04:45      1
# 2023-09-08 04:00      1
# 2023-09-01 04:45      1
# 2023-09-10 03:45      1
# 2023-09-07 04:00      1
# Name: count, Length: 70, dtype: int64

# %%
data['last_updated_epoch'].value_counts()
# Out:
# last_updated_epoch
# 1693525500    544
# 1693286100    543
# 1693698300    541
# 1694473200    540
# 1694701800    539
# 1694127600    482
# 1694558700    462
# 1694300400    461
# 1693784700    446
# 1694214000    441
# 1693956600    433
# 1694386800    433
# 1693870200    416
# 1693611900    413
# 1694042100    373
# 1694730600    342
# 1693439100    324
# 1693365300    323
# 1693366200    227
# 1693440000    226
# 1694731500    208
# 1694041200    172
# 1693612800    136
# 1693871100    133
# 1693955700    112
# 1694385900    112
# 1694213100    109
# 1693783800     98
# 1694559600     86
# 1694299500     84
# 1694128500     67
# 1694472300      6
# 1694700900      5
# 1693699200      3
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['country', 'location_name', 'region', 'latitude', 'longitude',
#        'timezone', 'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='object')

# %%
print(data['sunrise'].head())
# Out:
# 0    05:59 AM
# 1    06:00 AM
# 2    05:56 AM
# 3    06:00 AM
# 4    06:01 AM
# Name: sunrise, dtype: object

# %%
print(data['moonrise'].head())
# Out:
# 0    05:42 PM
# 1    05:39 PM
# 2    05:32 PM
# 3    05:36 PM
# 4    05:38 PM
# Name: moonrise, dtype: object

# %%
data['sunrise'] = pd.to_datetime(data['sunrise']).dt.strftime('%H:%M:%S')
data['sunrise'] = pd.to_datetime(data['sunrise'], format='%H:%M:%S')

print(data['sunrise'].head())
# Out:
# 0   1900-01-01 05:59:00
# 1   1900-01-01 06:00:00
# 2   1900-01-01 05:56:00
# 3   1900-01-01 06:00:00
# 4   1900-01-01 06:01:00
# Name: sunrise, dtype: datetime64[ns]

# %%
data['sunset'] = pd.to_datetime(data['sunset']).dt.strftime('%H:%M:%S')
data['sunset'] = pd.to_datetime(data['sunset'], format='%H:%M:%S')

print(data['sunset'].head())
# Out:
# 0   1900-01-01 18:41:00
# 1   1900-01-01 18:40:00
# 2   1900-01-01 18:34:00
# 3   1900-01-01 18:38:00
# 4   1900-01-01 18:39:00
# Name: sunset, dtype: datetime64[ns]

# %%
# Replace 'No moonrise' with NaN
data['moonrise'] = data['moonrise'].replace('No moonrise', np.nan)

# Convert valid entries to datetime
data['moonrise'] = pd.to_datetime(data['moonrise'], format='%I:%M %p', errors='coerce')

print(data['moonrise'].head())
# Out:
# 0   1900-01-01 17:42:00
# 1   1900-01-01 17:39:00
# 2   1900-01-01 17:32:00
# 3   1900-01-01 17:36:00
# 4   1900-01-01 17:38:00
# Name: moonrise, dtype: datetime64[ns]

# %%
# Replace 'No moonrise' with NaN
data['moonset'] = data['moonset'].replace('No moonrise', np.nan)

# Convert valid entries to datetime
data['moonset'] = pd.to_datetime(data['moonset'], format='%I:%M %p', errors='coerce')

print(data['moonset'].head())
# Out:
# 0   1900-01-01 03:38:00
# 1   1900-01-01 03:41:00
# 2   1900-01-01 03:39:00
# 3   1900-01-01 03:43:00
# 4   1900-01-01 03:42:00
# Name: moonset, dtype: datetime64[ns]

# %%
data['moon_phase'].value_counts()
# Out:
# moon_phase
# Waning Crescent    3283
# Waning Gibbous     3275
# Full Moon          1100
# New Moon           1094
# Last Quarter        545
# Waxing Gibbous      543
# Name: count, dtype: int64

# %%
print(data['condition_text'].head())
# Out:
# 0    Partly cloudy
# 1            Sunny
# 2    Partly cloudy
# 3           Cloudy
# 4           Cloudy
# Name: condition_text, dtype: object

# %%
data['condition_text'].value_counts()
# Out:
# condition_text
# Clear                                  2423
# Partly cloudy                          1866
# Mist                                   1395
# Light rain shower                       949
# Patchy rain possible                    943
# Sunny                                   772
# Cloudy                                  414
# Moderate or heavy rain shower           244
# Overcast                                239
# Fog                                     216
# Light rain                              103
# Moderate or heavy rain with thunder      55
# Moderate rain                            40
# Torrential rain shower                   30
# Light drizzle                            29
# Thundery outbreaks possible              26
# Moderate rain at times                   23
# Patchy light drizzle                     21
# Patchy light rain                        19
# Heavy rain                               17
# Patchy light rain with thunder            8
# ...

# %%
data['air_quality_us-epa-index'].value_counts()
# Out:
# air_quality_us-epa-index
# 1    3794
# 2    2867
# 4    1515
# 3    1403
# 5     241
# 6      20
# Name: count, dtype: int64

# %%
data['air_quality_gb-defra-index'].value_counts()
# Out:
# air_quality_gb-defra-index
# 1     3099
# 2     1889
# 10    1558
# 3     1265
# 4      534
# 5      425
# 6      354
# 8      258
# 9      238
# 7      220
# Name: count, dtype: int64

# %%
data['wind_degree'].head()
# Out:
# 0    281
# 1    287
# 2    317
# 3    297
# 4    274
# Name: wind_degree, dtype: int64

# %%
data['wind_degree'].describe()
# Out:
# count    9840.000000
# mean      194.218496
# std        98.014747
# min         1.000000
# 25%       100.000000
# 50%       233.000000
# 75%       271.250000
# max       360.000000
# Name: wind_degree, dtype: float64

# %%
data['wind_direction'].value_counts()
# Out:
# wind_direction
# W      1523
# WSW    1392
# WNW     916
# E       694
# ENE     647
# NE      569
# SW      556
# NW      524
# SE      517
# ESE     452
# N       395
# SSE     337
# NNE     335
# SSW     331
# NNW     329
# S       323
# Name: count, dtype: int64

# %%
data['uv_index'].describe()
# Out:
# count    9840.000000
# mean        2.028252
# std         2.246207
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         9.000000
# Name: uv_index, dtype: float64

# %%
data['uv_index'].value_counts()
# Out:
# uv_index
# 1.0    8077
# 7.0     747
# 8.0     417
# 6.0     373
# 5.0     166
# 4.0      43
# 3.0       7
# 9.0       5
# 2.0       5
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt


data.hist(bins=50 , figsize=(12,8))
plt.tight_layout()
plt.show()

# %%
data.plot(kind="scatter", x="longitude", y="latitude", grid=True)
plt.show()

# %%
data.plot(kind="scatter", x="longitude", y="latitude", grid=True,
             s=data["temperature_celsius"], label="temp",
             c="temperature_celsius", cmap="jet", colorbar=True,
             legend=True, sharex=False, figsize=(10, 7))
plt.show()

# %%
data.plot(kind="scatter", x="longitude", y="latitude", grid=True,
             s=data["feels_like_celsius"], label="feels_like_celsius",
             c="feels_like_celsius", cmap="jet", colorbar=True,
             legend=True, sharex=False, figsize=(10, 7))
plt.show()

# %%
data.plot(kind="scatter", x="longitude", y="latitude", grid=True,
             s=data["humidity"], label="humidity",
             c="humidity", cmap="jet", colorbar=True,
             legend=True, sharex=False, figsize=(10, 7))
plt.show()

# %%
data.plot(kind="scatter", x="longitude", y="latitude", grid=True,
             s=data["uv_index"], label="uv_index",
             c="uv_index", cmap="jet", colorbar=True,
             legend=True, sharex=False, figsize=(10, 7))
plt.show()

# %%
data.plot(kind="scatter", x="longitude", y="latitude", grid=True,
             s=data["moon_illumination"], label="moon_illumination",
             c="moon_illumination", cmap="jet", colorbar=True,
             legend=True, sharex=False, figsize=(10, 7))
plt.show()

# %%
data.plot(kind="scatter", x="longitude", y="latitude", grid=True,
             s=data["wind_mph"], label="wind_mph",
             c="wind_mph", cmap="jet", colorbar=True,
             legend=True, sharex=False, figsize=(10, 7))
plt.show()

# %%
data.plot(kind="scatter", x="longitude", y="latitude", grid=True,
             s=data["gust_mph"], label="gust_mph",
             c="gust_mph", cmap="jet", colorbar=True,
             legend=True, sharex=False, figsize=(10, 7))
plt.show()

# %%
data.plot(kind="scatter", x="longitude", y="latitude", grid=True,
             s=data["precip_mm"], label="precip_mm",
             c="precip_mm", cmap="jet", colorbar=True,
             legend=True, sharex=False, figsize=(10, 7))
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9840 entries, 0 to 9839
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       9840 non-null   object
#  1   location_name                 9840 non-null   object
#  2   region                        9840 non-null   object
#  3   latitude                      9840 non-null   float64
#  4   longitude                     9840 non-null   float64
#  5   timezone                      9840 non-null   object
#  6   last_updated_epoch            9840 non-null   int64
#  7   last_updated                  9840 non-null   object
#  8   temperature_celsius           9840 non-null   float64
#  9   temperature_fahrenheit        9840 non-null   float64
#  10  condition_text                9840 non-null   object
#  11  wind_mph                      9840 non-null   float64
# ...

# %%
data.plot(kind="scatter", x="longitude", y="latitude", grid=True,
             s=data["air_quality_Ozone"], label="air_quality_Ozone",
             c="air_quality_Ozone", cmap="jet", colorbar=True,
             legend=True, sharex=False, figsize=(10, 7))
plt.show()

# %%
df = pd.DataFrame(data[['sunrise','cloud']])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9840 entries, 0 to 9839
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sunrise  9840 non-null   datetime64[ns]
#  1   cloud    9840 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 153.9 KB

# %%
df = df.sort_values("sunrise").set_index("sunrise")
df.head()
# Out:
#                      cloud
# sunrise
# 1900-01-01 04:44:00     32
# 1900-01-01 04:45:00     74
# 1900-01-01 04:45:00     89
# 1900-01-01 04:45:00     12
# 1900-01-01 04:46:00     50

# %%
df.tail()
# Out:
#                      cloud
# sunrise
# 1900-01-01 06:39:00     86
# 1900-01-01 06:39:00     34
# 1900-01-01 06:40:00     26
# 1900-01-01 06:40:00      6
# 1900-01-01 06:40:00     17

# %%
df["1900-01-01 04:44:00":"1900-01-01 06:40:00"].plot(grid=True , marker=".",figsize=(18,12))
plt.show()

# %%
df = pd.DataFrame(data[['sunset','cloud']])
df = df.sort_values("sunset").set_index("sunset")
df.head()
# Out:
#                      cloud
# sunset
# 1900-01-01 17:13:00     82
# 1900-01-01 17:13:00     16
# 1900-01-01 17:15:00    100
# 1900-01-01 17:15:00     89
# 1900-01-01 17:16:00     52

# %%
df.tail()
# Out:
#                      cloud
# sunset
# 1900-01-01 19:12:00      9
# 1900-01-01 19:13:00     14
# 1900-01-01 19:13:00     16
# 1900-01-01 19:13:00     75
# 1900-01-01 19:14:00     52

# %%
df["1900-01-01 17:13:00":"1900-01-01 19:14:00"].plot(grid=True , marker=".",figsize=(18,12))
plt.show()

# %%
import seaborn as sn
ax = sn.countplot(x='moon_phase',data=data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.figure(figsize=(12,10))
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9840 entries, 0 to 9839
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       9840 non-null   object
#  1   location_name                 9840 non-null   object
#  2   region                        9840 non-null   object
#  3   latitude                      9840 non-null   float64
#  4   longitude                     9840 non-null   float64
#  5   timezone                      9840 non-null   object
#  6   last_updated_epoch            9840 non-null   int64
#  7   last_updated                  9840 non-null   object
#  8   temperature_celsius           9840 non-null   float64
#  9   temperature_fahrenheit        9840 non-null   float64
#  10  condition_text                9840 non-null   object
#  11  wind_mph                      9840 non-null   float64
# ...

# %%
data.columns
# Out:
# Index(['country', 'location_name', 'region', 'latitude', 'longitude',
#        'timezone', 'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='object')

# %%
data_reduced = data.drop(['temperature_fahrenheit','country','region','timezone','last_updated_epoch','last_updated','temperature_fahrenheit','wind_kph',
       'feels_like_fahrenheit', 'visibility_km','gust_kph'],axis=1)

# %%
csv_file_path = 'C:/Users/Aravind/Work/PROJECTS/Cloudburst-Prediction-System/data/interim/Data-reduced.csv'
data_reduced.to_csv(csv_file_path, index=False)
